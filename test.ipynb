# %% [markdown]
# ## YouTube Video Fetching

# %%
# Import the necessary modules
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# Prompt the user to enter their API key
api_key = input("AIzaSyBCCQ7xiC0Jxe29uIe9DCg-rBsUpV1LNcU")

# Initialize the YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Search for news-related videos
video_ids = []
next_page_token = None

while len(video_ids) < 100:
    try:
        search_response = youtube.search().list(
            q='entertainment',
            type='video',
            videoDefinition='high',
            videoDuration='short',
            part='id',
            maxResults=50,
            pageToken=next_page_token
        ).execute()

        # Extract the video IDs from the search results
        video_ids.extend([item['id']['videoId'] for item in search_response['items']])
        next_page_token = search_response.get('nextPageToken')

        if next_page_token is None:
            break

    except HttpError as e:
        print('An error occurred: %s' % e)
        break

# Download the video links and save them to a text file
with open('entertainment_videos.txt', 'w') as f:
    for video_id in video_ids[:100]:
        video_url = f'https://www.youtube.com/watch?v={video_id}'
        f.write(video_url + '\n')
# Out:
# /home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?q=entertainment&type=video&videoDefinition=high&videoDuration=short&part=id&maxResults=50&alt=json returned "Request had insufficient authentication scopes.". Details: "[{'message': 'Insufficient Permission', 'domain': 'global', 'reason': 'insufficientPermissions'}]">

# %% [markdown]
# ## Data Preprocessing

# %%
import cv2
import os

def extract_frames(video_path, output_dir, num_frames=16):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video
    num_frames_total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the step size for the sliding window based on the desired number of frames
    step_size = max(num_frames_total // num_frames, 1)

    # Initialize the current frame number and the frame counter
    frame_num = 0
    count = 0

    # Loop through the video frames and extract a frame every step_size frames
    while True:
        # Read the current frame
        ret, frame = cap.read()

        # If we've reached the end of the video, break out of the loop
        if not ret:
            break

        # If the current frame number is a multiple of the step size, save the frame
        if frame_num % step_size == 0:
            # Construct the output filename
            output_path = os.path.join(output_dir, f'frame_{count:04d}.jpg')

            # Save the frame to disk
            cv2.imwrite(output_path, frame)

            # Increment the frame counter
            count += 1

        # Increment the current frame number
        frame_num += 1

    # Release the video file
    cap.release()

    # Return the total number of frames extracted
    return count

# Define the input and output directories
input_dir = 'Video_Data/validate/CricketBowling'
output_dir = 'Video_Data/train/CricketBowling_frames'



# Number of frames to extract from each video
num_frames = 16

# Loop through all video files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.mp4') or filename.endswith('.avi'):
        # Path to input and output files
        input_file = os.path.join(input_dir, filename)
        output_file = os.path.join(output_dir, os.path.splitext(filename)[0])

        # Create the output directory if it doesn't exist
        if not os.path.exists(output_file):
            os.makedirs(output_file)

        # Extract frames from the video file
        extract_frames(input_file, output_file, num_frames)

        print(f'{num_frames} frames extracted from {input_file} and saved to {output_file}')
# Out:
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g20_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g20_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g20_c04.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g20_c04
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c01.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c01
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g22_c02.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g22_c02
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c05.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c05
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c06.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c06
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c04.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c04
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c02.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c02
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g20_c02.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g20_c02
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g17_c04.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g17_c04
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c01.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c01
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g22_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g22_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g22_c01.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g22_c01
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c06.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c06
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c02.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c02
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c05.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c05
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c05.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c05
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c07.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c07
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c01.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c01
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g18_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g18_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g17_c05.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g17_c05
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c02.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c02
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c06.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c06
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g20_c01.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g20_c01
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g19_c04.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g19_c04
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g21_c04.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g21_c04
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g17_c03.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g17_c03
# 16 frames extracted from Video_Data/validate/CricketBowling/v_CricketBowling_g20_c05.avi and saved to Video_Data/train/CricketBowling_frames/v_CricketBowling_g20_c05

# %% [markdown]
# ## Extract and Resize

# %%
from PIL import Image
import os
import uuid

# Set the paths for the input and output directories
input_dir = "Video_Data/train/ThrowDiscus_frames"
output_dir = "Data/ThrowDiscus"

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through all the subdirectories of the input directory
for subdir in os.listdir(input_dir):
    subdir_path = os.path.join(input_dir, subdir)
    if os.path.isdir(subdir_path):
        # Loop through all the image files in the subdirectory
        for filename in os.listdir(subdir_path):
            if filename.endswith(".jpg") or filename.endswith(".png"):
                # Open the image and resize it to 64x64
                image_path = os.path.join(subdir_path, filename)
                image = Image.open(image_path)
                resized_image = image.resize((640, 640))

                # Generate a unique filename and save the resized image to the output directory
                unique_filename = str(uuid.uuid4()) + ".jpg"
                output_path = os.path.join(output_dir, unique_filename)
                resized_image.save(output_path)

# %% [markdown]
# ## Data Spliting

# %% [markdown]
# ## Model Training

# %%
# !yolo classify train model=yolov8n-cls.pt data=dataset epochs=100 batch=128 imgsz=128 workers=8 patience=10 cache=True device=0
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/home/ai/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████████████████████████████████| 5.31M/5.31M [00:02<00:00, 2.39MB/s]
# Ultralytics YOLOv8.2.88 🚀 Python-3.9.19 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3896MiB)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=dataset, epochs=100, time=None, patience=10, batch=128, imgsz=128, save=True, save_period=-1, cache=True, device=0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train
# train: /home/ai/Desktop/YOLO_Vid_Classification/dataset/train... found 4063 images in 3 classes ✅
# val: None...
# test: /home/ai/Desktop/YOLO_Vid_Classification/dataset/test... found 752 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 99 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:03<00:00, 1.65MB/s]
# AMP: checks passed ✅
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# train: Scanning /home/ai/Desktop/YOLO_Vid_Classification/dataset/train... 4063 i
# train: New cache created: /home/ai/Desktop/YOLO_Vid_Classification/dataset/train.cache
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# val: Scanning /home/ai/Desktop/YOLO_Vid_Classification/dataset/test... 752 image
# val: New cache created: /home/ai/Desktop/YOLO_Vid_Classification/dataset/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.001), 27 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 8 dataloader workers
# Logging results to runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.612G      1.104        128        128:  38%|███▊      | 12/32 Downloading https://ultralytics.com/assets/Arial.ttf to '/home/ai/.config/Ultralytics/Arial.ttf'...
#       1/100     0.612G     0.9007         95        128: 100%|██████████| 32/32
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,
#                    all      0.896          1
#
#       Epoch    GPU_mem       loss  Instances       Size
images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,
#                    all          1          1
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train
# Results saved to runs/classify/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## Predict

# %%
# !yolo task=classify mode=predict model=runs/classify/train/weights/best.pt conf=0.25 source=v_ApplyEyeMakeup_g25_c03.avi
# Out:
# Ultralytics YOLOv8.2.88 🚀 Python-3.9.19 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3896MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
#
# video 1/1 (frame 1/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 CricketBowling 0.53, JavelineThrow 0.47, ThrowDiscus 0.00, 1.7ms
# video 1/1 (frame 2/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.83, CricketBowling 0.17, ThrowDiscus 0.00, 1.3ms
# video 1/1 (frame 3/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.81, CricketBowling 0.19, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 4/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.79, CricketBowling 0.21, ThrowDiscus 0.00, 1.6ms
# video 1/1 (frame 5/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.82, CricketBowling 0.18, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 6/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.74, CricketBowling 0.26, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 7/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.83, CricketBowling 0.17, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 8/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.75, CricketBowling 0.25, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 9/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.68, CricketBowling 0.32, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 10/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.67, CricketBowling 0.33, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 11/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.54, CricketBowling 0.46, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 12/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.53, CricketBowling 0.47, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 13/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.54, CricketBowling 0.46, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 14/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.87, CricketBowling 0.13, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 15/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.84, CricketBowling 0.16, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 16/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.83, CricketBowling 0.16, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 17/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.87, CricketBowling 0.13, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 18/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.15, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 19/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.89, CricketBowling 0.11, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 20/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.15, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 21/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.91, CricketBowling 0.09, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 22/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.90, CricketBowling 0.10, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 23/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.86, CricketBowling 0.14, ThrowDiscus 0.00, 1.4ms
# video 1/1 (frame 24/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.15, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 25/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.15, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 26/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.83, CricketBowling 0.17, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 27/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.93, CricketBowling 0.07, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 28/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.94, CricketBowling 0.06, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 29/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.82, CricketBowling 0.18, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 30/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.81, CricketBowling 0.19, ThrowDiscus 0.00, 1.9ms
# video 1/1 (frame 31/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.76, CricketBowling 0.24, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 32/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.77, CricketBowling 0.23, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 33/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.77, CricketBowling 0.23, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 34/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.67, CricketBowling 0.33, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 35/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.69, CricketBowling 0.31, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 36/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.69, CricketBowling 0.31, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 37/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.64, CricketBowling 0.36, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 38/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.63, CricketBowling 0.37, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 39/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.14, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 40/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.84, CricketBowling 0.16, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 41/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.60, CricketBowling 0.39, ThrowDiscus 0.01, 1.0ms
# video 1/1 (frame 42/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.50, CricketBowling 0.50, ThrowDiscus 0.00, 1.7ms
# video 1/1 (frame 43/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.51, CricketBowling 0.49, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 44/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.67, CricketBowling 0.33, ThrowDiscus 0.00, 1.2ms
# video 1/1 (frame 45/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.65, CricketBowling 0.35, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 46/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.90, CricketBowling 0.10, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 47/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.89, CricketBowling 0.09, ThrowDiscus 0.01, 1.0ms
# video 1/1 (frame 48/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.90, CricketBowling 0.09, ThrowDiscus 0.01, 1.0ms
# video 1/1 (frame 49/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.97, CricketBowling 0.03, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 50/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.97, CricketBowling 0.03, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 51/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.85, CricketBowling 0.15, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 52/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.82, CricketBowling 0.18, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 53/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.81, CricketBowling 0.19, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 54/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.62, CricketBowling 0.38, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 55/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.60, CricketBowling 0.40, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 56/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0
125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.54, CricketBowling 0.46, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 122/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.72, CricketBowling 0.28, ThrowDiscus 0.00, 1.5ms
# video 1/1 (frame 123/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.71, CricketBowling 0.29, ThrowDiscus 0.00, 1.0ms
# video 1/1 (frame 124/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.77, CricketBowling 0.23, ThrowDiscus 0.00, 1.1ms
# video 1/1 (frame 125/125) /home/ai/Desktop/YOLO_Vid_Classification/v_ApplyEyeMakeup_g25_c03.avi: 128x128 JavelineThrow 0.78, CricketBowling 0.22, ThrowDiscus 0.00, 1.3ms
# Speed: 1.1ms preprocess, 1.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math

cap = cv2.VideoCapture(0)  # For Webcam
cap.set(3, 640)
cap.set(4, 480)


model = YOLO("runs/detect/train/weights/best.pt")
classNames = ['Cricket', 'javelin', 'Throw']


while True:
    success, img = cap.read()
    results = model(img, stream=True)
    for r in results:
        boxes = r.boxes
        for box in boxes:

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            # cv2.rectangle(img, (x1, y1), (x2, y2), (250, 0, 255), 3)        

            w, h = x2 - x1, y2 - y1
            cvzone.cornerRect(img, (x1, y1, w, h))

            conf = math.ceil((box.conf[0] * 100)) / 100

            cls = int(box.cls[0])
            cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=0.7, thickness=1)

    cv2.imshow("Image", img)
    cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 3
#       1 from ultralytics import YOLO
#       2 import cv2
# ----> 3 import cvzone
#       4 import math
#       6 cap = cv2.VideoCapture(0)  # For Webcam
#
# ModuleNotFoundError: No module named 'cvzone'

# %%
import gradio as gr
import cv2
import numpy as np
from ultralytics import YOLO
from timeit import default_timer as timer
import os

# catgories
format = {   0: 'Cricket',
             1: 'javelin',
             2: 'Throw'
             }

# returning classifiers output
def video_classifier(inp):
    model = YOLO("runs/classify/train/weights/best.pt")

    result = model.predict(source=inp)
    prob = result[0].probs
    max_tensor = max(prob)
    tensor_pos = ((prob == max_tensor).nonzero(as_tuple=True)[0])

    return format.get(int(tensor_pos))

# gradio code block for input and output
with gr.Blocks() as app:
    gr.Markdown("## Video classification using Yolov8")
    with gr.Row():
        inp_video = gr.Video()
        out_txt = gr.Textbox()
    btn = gr.Button(value="Submit")
    btn.click(video_classifier, inputs=inp_video, outputs=out_txt)



app.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# WARNING ⚠️ 'source' is missing. Using 'source=/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/ultralytics/assets'.
#
# image 1/2 /home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/ultralytics/assets/bus.jpg: 128x128 JavelineThrow 0.77, ThrowDiscus 0.20, CricketBowling 0.03, 3.1ms
# image 2/2 /home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/ultralytics/assets/zidane.jpg: 128x128 JavelineThrow 0.96, CricketBowling 0.04, ThrowDiscus 0.00, 1.3ms
# Speed: 6.1ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Traceback (most recent call last):
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/gradio/route_utils.py", line 321, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/home/ai/miniconda3/envs/ultralytics/lib/python3.9/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#   File "/tmp/ipykernel_10994/3021494942.py", line 20, in video_classifier
#     max_tensor = max(prob)
# TypeError: '>' not supported between instances of 'Probs' and 'Probs'
